# %% [markdown]
# ## Data loading - YLFW Benchmark
# Source: https://github.com/JessyFrish/YLFW_Links?tab=readme-ov-file
#
# Make suitable for ArcFace and MagFace (112x112) and FaceNet (160x160)

# %% [markdown]
# ### Data folder structure and metadata

# %%
# Load packages

# Common
import pandas as pd
import numpy as np
import os
import cv2 as cv
from IPython.display import clear_output as cls
import json

# Data
from glob import glob

# Data Visuaalization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ### Descriptive analysis of data

# %% [markdown]
# #### Data concatenation

# %%
import os
os.getcwd()
# Out:
# '/mnt/c/Dokumenter/Dokumenter/UNI/Master/Thesis/GitHub_Repo/Master_Thesis/notebooks/loadings'

# %%
# ## Create dataframe

# # Define the path to the raw data directory
# raw_data_path = '../../data/data_full/'

# # Initialize lists to store image characteristics
# img_names = []
# id_class = []
# ethnicities = []

# # Iterate through the directories of each ethnicity (e.g., 'Asian')
# ethnicities_list = os.listdir(raw_data_path + 'children_full')
# #To ensure DS Store is not included. DELETE files with '.'
# ethnicities_list = [x for x in ethnicities_list if not x.startswith(".")]

# for ethnicity in ethnicities_list:
#     ethnicity_col = ethnicity.split('_')[0]
#     id = int(ethnicity.split('_')[1:][0])
#     ethnicity_dir = os.path.join(raw_data_path + 'children_full', ethnicity)
#     if os.path.isdir(ethnicity_dir):
#         # Iterate through image files in the ethnicity directory
#         for img_name in os.listdir(ethnicity_dir):
#             # Append image characteristics to lists
#             img_name = img_name.split('.')[0]
#             img_names.append(img_name)
#             ethnicities.append(ethnicity_col)


# # Create a DataFrame from the lists
# data = {'image_name': img_names, 'ethnicity': ethnicities}
# df = pd.DataFrame(data)

# # Display the DataFrame
# print("len of df", len(df))
# print("\nisna?", df.isna().sum())
# df.head()

# %%
# # Read the JSON file into a JSON variable
# with open('/mnt/c/Dokumenter/Dokumenter/UNI/Master/Thesis/GitHub_Repo/Master_Thesis/data/age_estimations/YLFW_output_data_precroped_all_age.json', 'r') as file:
#     json_data = json.load(file)

# # Convert the JSON data to a DataFrame
# age_df = pd.DataFrame.from_dict(json_data, orient='index', columns=['Age'])
# # Convert the 'Age' column to numeric
# age_df['Age'] = pd.to_numeric(age_df['Age'])
# age_df.reset_index(inplace=True)
# age_df.columns = ['image_name', 'Age']

# print("len of age df",len(age_df))
# print("isna", age_df.isna().sum())
# age_df.head()
# Out:
# len of age df 9810
# isna image_name      0
# Age           581
# dtype: int64
#           image_name   Age
# 0  Caucasian_1008_18   8.0
# 1       Asian_225_72  11.0
# 2        Asian_238_1   3.0
# 3  Caucasian_1110_17   4.0
# 4   Caucasian_364_12   2.0

# %%
# # Concatenate dataframes
# final_df = pd.merge(age_df, df, on='image_name', how='inner')
# print("len of final df",len(final_df))
# print("isna?",final_df.isna().sum())
# final_df.head()
# Out:
# len of final df 9810
# isna? image_name      0
# Age           581
# ethnicity       0
# dtype: int64
#           image_name   Age  ethnicity
# 0  Caucasian_1008_18   8.0  Caucasian
# 1       Asian_225_72  11.0      Asian
# 2        Asian_238_1   3.0      Asian
# 3  Caucasian_1110_17   4.0  Caucasian
# 4   Caucasian_364_12   2.0  Caucasian

# %%
# combine
mated_children_image_info = pd.read_csv('../../data/image_info_csvs/mated_children_image_info.csv')
nonmated_children_image_info = pd.read_csv('../../data/image_info_csvs/nonmated_children_image_info.csv')

final_df = pd.concat([mated_children_image_info,nonmated_children_image_info])

# %%
#duplicates?
final_df["image_name"].duplicated().sum()
# Out:
# 0

# %%
final_df.duplicated().sum()
# Out:
# 0

# %%
# age_df.isna().sum()

# %%
# isna_age = final_df[final_df.Age.isna()]

# %% [markdown]
# Relatively balanced with Caucasian being the most represented - We remove

# %%
final_df.ethnicity.value_counts(normalize=True)
# Out:
# Caucasian    0.283066
# Asian        0.275612
# African      0.232195
# Indian       0.209127
# Name: ethnicity, dtype: float64

# %%
final_df.ethnicity.value_counts(normalize=True)
# Out:
# Caucasian    0.283066
# Asian        0.275612
# African      0.232195
# Indian       0.209127
# Name: ethnicity, dtype: float64

# %%
# Remove NaN values
print(len(final_df))
final_df.dropna(inplace=True)
print("len of final df",len(final_df))
# Out:
# 9927
# len of final df 9195

# %%
# Ensure 'Age' is of type integer
final_df['Age'] = final_df['Age'].astype(int)

# Define the age groups and corresponding labels
age_bins = [1, 4, 7, 10, 13, 16]
age_labels = ['1-3', '4-6', '7-9', '10-12', '13-15']

# Update the DataFrame with age groupings
final_df['children_agegroup'] = pd.cut(final_df['Age'], bins=age_bins, labels=age_labels, right=False)

# %%
# Remove NaN values
print(len(final_df))
final_df.dropna(inplace=True)
print("len of final df",len(final_df))
# Out:
# 9195
# len of final df 7325

# %%
final_df.head()
# Out:
#                     files_list    image_name  enrolled identity_name  \
# 0    African_0/African_0_0.png   African_0_0  enrolled     African_0
# 1   African_1/African_1_11.png  African_1_11  enrolled     African_1
# 2    African_1/African_1_4.png   African_1_4  enrolled     African_1
# 3  African_10/African_10_1.png  African_10_1  enrolled    African_10
# 4  African_10/African_10_3.png  African_10_3  enrolled    African_10
#
#   ethnicity  Age    Identity  UnifiedQualityScore.scalar  HeadPoseYaw.scalar  \
# 0   African    7   African_0                        34.0               100.0
# 1   African    5   African_1                        65.0               100.0
# 2   African    2   African_1                        23.0                95.0
# 3   African    5  African_10                        50.0               100.0
# 4   African    6  African_10                        25.0                90.0
#
#    HeadPosePitch.scalar  HeadPoseRoll.scalar children_agegroup
# 0                  93.0                100.0               7-9
# 1                  99.0                100.0               4-6
# 2                  99.0                100.0               1-3
# 3                  97.0                100.0               4-6
# 4                 100.0                100.0               4-6

# %%
final_df[final_df['children_agegroup'] == '13-15']
# Out:
#                           files_list      image_name      enrolled  \
# 10     African_109/African_109_3.png   African_109_3      enrolled
# 16     African_113/African_113_0.png   African_113_0      enrolled
# 34    African_119/African_119_14.png  African_119_14      enrolled
# 48     African_121/African_121_2.png   African_121_2      enrolled
# 55     African_127/African_127_6.png   African_127_6      enrolled
# ...                              ...             ...           ...
# 7298       Indian_64/Indian_64_0.png     Indian_64_0  non_enrolled
# 7303     Indian_664/Indian_664_0.png    Indian_664_0  non_enrolled
# 7308         Indian_7/Indian_7_0.png      Indian_7_0  non_enrolled
# 7314       Indian_74/Indian_74_0.png     Indian_74_0  non_enrolled
# 7320       Indian_91/Indian_91_0.png     Indian_91_0  non_enrolled
#
#      identity_name ethnicity  Age     Identity  UnifiedQualityScore.scalar  \
# 10     African_109   African   13  African_109                        10.0
# 16     African_113   African   15  African_113                        11.0
# 34     African_119   African   15  African_119                        15.0
# 48     African_121   African   13  African_121                         8.0
# 55     African_127   African   15  African_127                        21.0
# ...            ...       ...  ...          ...                         ...
# 7298     Indian_64    Indian   14    Indian_64                        50.0
# 7303    Indian_664    Indian   13   Indian_664                        61.0
# 7308      Indian_7    Indian   13     Indian_7                        26.0
# 7314     Indian_74    Indian   14    Indian_74                        38.0
# 7320     Indian_91    Indian   15    Indian_91                        36.0
#
#       HeadPoseYaw.scalar  HeadPosePitch.scalar  HeadPoseRoll.scalar  \
# 10                 100.0                  78.0                100.0
# 16                  98.0                  68.0                100.0
# 34                 100.0                  96.0                100.0
# 48                  84.0                 100.0                100.0
# 55                 100.0                  80.0                100.0
# ...                  ...                   ...                  ...
# 7298                96.0                  99.0                100.0
# 7303               100.0                  92.0                100.0
# 7308                99.0                  94.0                100.0
# 7314               100.0                  92.0                100.0
# 7320                95.0                  99.0                100.0
#
#      children_agegroup
# 10               13-15
# 16               13-15
# 34               13-15
# 48               13-15
# 55               13-15
# ...                ...
# 7298             13-15
# 7303             13-15
# 7308             13-15
# 7314             13-15
# 7320             13-15
#
# [458 rows x 12 columns]

# %% [markdown]
# #### Data distributions
# (Evt efter age groups)

# %%
plt.hist(final_df['Age'], color='skyblue')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %%
# Define bin edges for each group of 3 years
bin_edges = [1, 4, 7, 10, 13, 16]
plt.hist(final_df['Age'], bins=age_bins, color='skyblue')
plt.xticks(bin_edges)
plt.xlabel('Age groups')
plt.ylabel('Frequency')
plt.title('Childrens age Distribution')
plt.show()

# %%
# Define bin edges for each group of 3 years
plt.hist(final_df['ethnicity'], bins=4, color='skyblue')
plt.xticks(final_df['ethnicity'])
plt.xlabel('Ethnicity')
plt.ylabel('Frequency')
plt.title('Ethnicity composition')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 3
#       1 # Define bin edges for each group of 3 years
#       2 plt.hist(final_df['ethnicity'], bins=5, color='skyblue')
# ----> 3 plt.xticks(final_df['ethnicity'])
#       4 plt.xlabel('Ethnicity')
#       5 plt.ylabel('Frequency')
#
# File ~/miniconda3/envs/Katrine_MLOps_env/lib/python3.10/site-packages/matplotlib/pyplot.py:1886, in xticks(ticks, labels, minor, **kwargs)
#    1883         raise TypeError("xticks(): Parameter 'labels' can't be set "
#    1884                         "without setting 'ticks'")
#    1885 else:
# -> 1886     locs = ax.set_xticks(ticks, minor=minor)
#    1888 if labels is None:
#    1889     labels = ax.get_xticklabels(minor=minor)
#
# File ~/miniconda3/envs/Katrine_MLOps_env/lib/python3.10/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~/miniconda3/envs/Katrine_MLOps_env/lib/python3.10/site-packages/matplotlib/axis.py:2074, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    2071 if labels is None and kwargs:
#    2072     raise ValueError('labels argument cannot be None when '
#    2073                      'kwargs are passed')
# -> 2074 result = self._set_tick_locations(ticks, minor=minor)
#    2075 if labels is not None:
#    2076     self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File ~/miniconda3/envs/Katrine_MLOps_env/lib/python3.10/site-packages/matplotlib/axis.py:2035, in Axis._set_tick_locations(self, ticks, minor)
#    2033 else:
#    2034     self.set_major_locator(locator)
# -> 2035     return self.get_major_ticks(len(ticks))
#
# File ~/miniconda3/envs/Katrine_MLOps_env/lib/python3.10/site-packages/matplotlib/axis.py:1602, in Axis.get_major_ticks(self, numticks)
#    1598     numticks = len(self.get_majorticklocs())
#    1600 while len(self.majorTicks) < numticks:
#    1601     # Update the new tick label properties from the old.
# -> 1602     tick = self._get_tick(major=True)
#    1603     self.majorTicks.append(tick)
#    1604     self._copy_tick_props(self.majorTicks[0], tick)
#
# File ~/miniconda3/envs/Katrine_MLOps_env/lib/python3.10/site-packages/matplotlib/axis.py:1551, in Axis._get_tick(self, major)
#    1547     raise NotImplementedError(
#    1548         f"The Axis subclass {self.__class__.__name__} must define "
#    1549         "_tick_class or reimplement _get_tick()")
#    1550 tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1551 return self._tick_class(self.axes, 0, major=major, **tick_kw)
#
# File ~/miniconda3/envs/Katrine_MLOps_env/lib/python3.10/site-packages/matplotlib/axis.py:417, in XTick.__init__(self, *args, **kwargs)
#     416 def __init__(self, *args, **kwargs):
# --> 417     super().__init__(*args, **kwargs)
#     418     # x in data coords, y in axes coords
#     419     ax = self.axes
#
# File ~/miniconda3/envs/Katrine_MLOps_env/lib/python3.10/site-packages/matplotlib/axis.py:156, in Tick.__init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kwargs)
#     153     grid_alpha = mpl.rcParams["grid.alpha"]
#     154 grid_kw = {k[5:]: v for k, v in kwargs.items()}
# --> 156 self.tick1line = mlines.Line2D(
#     157     [], [],
#     158     color=color, linestyle="none", zorder=zorder, visible=tick1On,
#     159     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     160 )
#     161 self.tick2line = mlines.Line2D(
#     162     [], [],
#     163     color=color, linestyle="none", zorder=zorder, visible=tick2On,
#     164     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     165 )
#     166 self.gridline = mlines.Line2D(
#     167     [], [],
#     168     color=grid_color, alpha=grid_alpha, visible=gridOn,
#     169     linestyle=grid_linestyle, linewidth=grid_linewidth, marker="",
#     170     **grid_kw,
#     171 )
#
# File ~/miniconda3/envs/Katrine_MLOps_env/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/Katrine_MLOps_env/lib/python3.10/site-packages/matplotlib/lines.py:308, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     272 @_api.make_keyword_only("3.6", name="linewidth")
#     273 def __init__(self, xdata, ydata,
#     274              linewidth=None,  # all Nones default to rc
#    (...)
#     293              **kwargs
#     294              ):
#     295     """
#     296     Create a `.Line2D` instance with *x* and *y* data in sequences of
#     297     *xdata*, *ydata*.
#    (...)
#     306
#     307     """
# --> 308     super().__init__()
#     310     # Convert sequences to NumPy arrays.
#     311     if not np.iterable(xdata):
#
# File ~/miniconda3/envs/Katrine_MLOps_env/lib/python3.10/site-packages/matplotlib/artist.py:201, in Artist.__init__(self)
#     198 # Normally, artist classes need to be queried for mouseover info if and
#     199 # only if they override get_cursor_data.
#     200 self._mouseover = type(self).get_cursor_data != Artist.get_cursor_data
# --> 201 self._callbacks = cbook.CallbackRegistry(signals=["pchanged"])
#     202 try:
#     203     self.axes = None
#
# File ~/miniconda3/envs/Katrine_MLOps_env/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:190, in CallbackRegistry.__init__(self, exception_handler, signals)
#     130 """
#     131 Handle registering, processing, blocking, and disconnecting
#     132 for a set of signals and callbacks:
#    (...)
#     183     handled signals.
#     184 """
#     186 # We maintain two mappings:
#     187 #   callbacks: signal -> {cid -> weakref-to-callback}
#     188 #   _func_cid_map: signal -> {weakref-to-callback -> cid}
# --> 190 def __init__(self, exception_handler=_exception_printer, *, signals=None):
#     191     self._signals = None if signals is None else list(signals)  # Copy it.
#     192     self.exception_handler = exception_handler
#
# KeyboardInterrupt:

# %% [markdown]
# #### Save df

# %%
final_df["identity_name"] = final_df["image_name"].apply(lambda x: "_".join(x.split("_")[:2]))
final_df
# Out:
#              image_name  Age  ethnicity children_agegroup   identity_name
# 0     Caucasian_1008_18    8  Caucasian               7-9  Caucasian_1008
# 1          Asian_225_72   11      Asian             10-12       Asian_225
# 2           Asian_238_1    3      Asian               0-3       Asian_238
# 3     Caucasian_1110_17    4  Caucasian               4-6  Caucasian_1110
# 4      Caucasian_364_12    2  Caucasian               0-3   Caucasian_364
# ...                 ...  ...        ...               ...             ...
# 9802       Indian_132_0   11     Indian             10-12      Indian_132
# 9805   Caucasian_367_13    8  Caucasian               7-9   Caucasian_367
# 9806        Asian_19_28   29      Asian               NaN        Asian_19
# 9807        Asian_554_5    3      Asian               0-3       Asian_554
# 9808        Indian_51_0   13     Indian             13-15       Indian_51
#
# [9229 rows x 5 columns]

# %%
final_df
# Out:
#                       files_list    image_name      enrolled identity_name  \
# 0      African_0/African_0_0.png   African_0_0      enrolled     African_0
# 2     African_1/African_1_11.png  African_1_11      enrolled     African_1
# 3      African_1/African_1_4.png   African_1_4      enrolled     African_1
# 4    African_10/African_10_1.png  African_10_1      enrolled    African_10
# 5    African_10/African_10_3.png  African_10_3      enrolled    African_10
# ..                           ...           ...           ...           ...
# 792    Indian_91/Indian_91_0.png   Indian_91_0  non_enrolled     Indian_91
# 793    Indian_92/Indian_92_6.png   Indian_92_6  non_enrolled     Indian_92
# 794    Indian_93/Indian_93_1.png   Indian_93_1  non_enrolled     Indian_93
# 795    Indian_96/Indian_96_0.png   Indian_96_0  non_enrolled     Indian_96
# 797    Indian_99/Indian_99_1.png   Indian_99_1  non_enrolled     Indian_99
#
#     ethnicity  Age    Identity  UnifiedQualityScore.scalar  \
# 0     African    7   African_0                        34.0
# 2     African    5   African_1                        65.0
# 3     African    2   African_1                        23.0
# 4     African    5  African_10                        50.0
# 5     African    6  African_10                        25.0
# ..        ...  ...         ...                         ...
# 792    Indian   15   Indian_91                        36.0
# 793    Indian    2   Indian_92                        22.0
# 794    Indian   10   Indian_93                        14.0
# 795    Indian    8   Indian_96                        44.0
# 797    Indian    2   Indian_99                         9.0
#
#      HeadPoseYaw.scalar  HeadPosePitch.scalar  HeadPoseRoll.scalar  \
# 0                 100.0                  93.0                100.0
# 2                 100.0                  99.0                100.0
# 3                  95.0                  99.0                100.0
# 4                 100.0                  97.0                100.0
# 5                  90.0                 100.0                100.0
# ..                  ...                   ...                  ...
# 792                95.0                  99.0                100.0
# 793               100.0                  95.0                100.0
# 794                97.0                  96.0                100.0
# 795                97.0                 100.0                100.0
# 797                84.0                 100.0                100.0
#
#     children_agegroup
# 0                 7-9
# 2                 4-6
# 3                 1-3
# 4                 4-6
# 5                 4-6
# ..                ...
# 792             13-15
# 793               1-3
# 794             10-12
# 795               7-9
# 797               1-3
#
# [7325 rows x 12 columns]

# %%
## Only run when you want to create new csv
final_df.to_csv('../../data/image_info_csvs/YLFW_full_info_excluding_adults.csv', index=False)

# %% [markdown]
# #### Concatenate with children age groups from adults data

# %%
final_df = pd.read_csv('../../data/image_info_csvs/YLFW_full_info_excluding_adults.csv')

# %%
final_df
# Out:
#                        files_list    image_name      enrolled identity_name  \
# 0       African_0/African_0_0.png   African_0_0      enrolled     African_0
# 1      African_1/African_1_11.png  African_1_11      enrolled     African_1
# 2       African_1/African_1_4.png   African_1_4      enrolled     African_1
# 3     African_10/African_10_1.png  African_10_1      enrolled    African_10
# 4     African_10/African_10_3.png  African_10_3      enrolled    African_10
# ...                           ...           ...           ...           ...
# 7320    Indian_91/Indian_91_0.png   Indian_91_0  non_enrolled     Indian_91
# 7321    Indian_92/Indian_92_6.png   Indian_92_6  non_enrolled     Indian_92
# 7322    Indian_93/Indian_93_1.png   Indian_93_1  non_enrolled     Indian_93
# 7323    Indian_96/Indian_96_0.png   Indian_96_0  non_enrolled     Indian_96
# 7324    Indian_99/Indian_99_1.png   Indian_99_1  non_enrolled     Indian_99
#
#      ethnicity  Age    Identity  UnifiedQualityScore.scalar  \
# 0      African    7   African_0                        34.0
# 1      African    5   African_1                        65.0
# 2      African    2   African_1                        23.0
# 3      African    5  African_10                        50.0
# 4      African    6  African_10                        25.0
# ...        ...  ...         ...                         ...
# 7320    Indian   15   Indian_91                        36.0
# 7321    Indian    2   Indian_92                        22.0
# 7322    Indian   10   Indian_93                        14.0
# 7323    Indian    8   Indian_96                        44.0
# 7324    Indian    2   Indian_99                         9.0
#
#       HeadPoseYaw.scalar  HeadPosePitch.scalar  HeadPoseRoll.scalar  \
# 0                  100.0                  93.0                100.0
# 1                  100.0                  99.0                100.0
# 2                   95.0                  99.0                100.0
# 3                  100.0                  97.0                100.0
# 4                   90.0                 100.0                100.0
# ...                  ...                   ...                  ...
# 7320                95.0                  99.0                100.0
# 7321               100.0                  95.0                100.0
# 7322                97.0                  96.0                100.0
# 7323                97.0                 100.0                100.0
# 7324                84.0                 100.0                100.0
#
#      children_agegroup
# 0                  7-9
# 1                  4-6
# 2                  1-3
# 3                  4-6
# 4                  4-6
# ...                ...
# 7320             13-15
# 7321               1-3
# 7322             10-12
# 7323               7-9
# 7324               1-3
#
# [7325 rows x 12 columns]

# %% [markdown]
# # Her skal der først laves en ny RFW_full_info_including_children

# %%
a_df = pd.read_csv('/mnt/c/Dokumenter/Dokumenter/UNI/Master/Thesis/GitHub_Repo/Master_Thesis/data/image_info_csvs/RFW_full_info_including_children.csv')

# %%
a_df
# Out:
#            image_name identity_name ethnicity  Age children_agegroup
# 0       m.010lz5_0001      m.010lz5   African   38               NaN
# 1       m.010lz5_0002      m.010lz5   African   29               NaN
# 2       m.010lz5_0003      m.010lz5   African   37               NaN
# 3       m.011y5k_0001      m.011y5k   African   40               NaN
# 4       m.011y5k_0002      m.011y5k   African   43               NaN
# ...               ...           ...       ...  ...               ...
# 37100  m.0vshsz9_0002     m.0vshsz9    Indian   36               NaN
# 37101  m.0vshsz9_0003     m.0vshsz9    Indian   25               NaN
# 37102    m.0_4pw_0002       m.0_4pw    Indian   64               NaN
# 37103    m.0_4pw_0003       m.0_4pw    Indian   37               NaN
# 37104    m.0_4pw_0004       m.0_4pw    Indian   51               NaN
#
# [37105 rows x 5 columns]

# %%
## 1. Add childrens age group to adult data
# Ensure 'Age' is of type integer
a_df['Age'] = a_df['Age'].astype(int)

# Define the age groups and corresponding labels
age_bins = [0, 4, 7, 10, 13, 16, 19]  # adding one more bin for 16-18
age_labels = ['0-3', '4-6', '7-9', '10-12', '13-15', '16-18']

# Update the DataFrame with age groupings
a_df['children_agegroup'] = pd.cut(a_df['Age'], bins=age_bins, labels=age_labels, right=False)

# Transfer childrens age groups in a_df to y_df
a_data_children_agegroup = a_df[a_df.children_agegroup.notnull()]

# Merge to ylfw
ylfw_witha = pd.concat([final_df,a_data_children_agegroup],ignore_index=True)

# %%
a_data_children_agegroup
# Out:
#            image_name identity_name ethnicity  Age children_agegroup
# 308    m.01mqdhm_0001     m.01mqdhm   African   17             16-18
# 859    m.02664bd_0001     m.02664bd   African    9               7-9
# 860    m.02664bd_0002     m.02664bd   African   11             10-12
# 921    m.026j8v2_0003     m.026j8v2   African   18             16-18
# 1151   m.027qhjc_0001     m.027qhjc   African   18             16-18
# ...               ...           ...       ...  ...               ...
# 36491  m.0jfgrjr_0004     m.0jfgrjr    Indian   16             16-18
# 36565  m.0jwwdq1_0001     m.0jwwdq1    Indian   16             16-18
# 36566  m.0jwwdq1_0002     m.0jwwdq1    Indian    6               4-6
# 36661   m.0k3208_0001      m.0k3208    Indian   18             16-18
# 37047  m.0r8ntwm_0003     m.0r8ntwm    Indian   18             16-18
#
# [698 rows x 5 columns]

# %%
len(ylfw_witha)
# Out:
# 9927

# %%
ylfw_witha
# Out:
#              image_name  Age  ethnicity children_agegroup   identity_name
# 0     Caucasian_1008_18    8  Caucasian               7-9  Caucasian_1008
# 1          Asian_225_72   11      Asian             10-12       Asian_225
# 2           Asian_238_1    3      Asian               0-3       Asian_238
# 3     Caucasian_1110_17    4  Caucasian               4-6  Caucasian_1110
# 4      Caucasian_364_12    2  Caucasian               0-3   Caucasian_364
# ...                 ...  ...        ...               ...             ...
# 9922     m.0jfgrjr_0004   16     Indian             16-18       m.0jfgrjr
# 9923     m.0jwwdq1_0001   16     Indian             16-18       m.0jwwdq1
# 9924     m.0jwwdq1_0002    6     Indian               4-6       m.0jwwdq1
# 9925      m.0k3208_0001   18     Indian             16-18        m.0k3208
# 9926     m.0r8ntwm_0003   18     Indian             16-18       m.0r8ntwm
#
# [9927 rows x 5 columns]

# %%
ylfw_witha.to_csv('../data/raw_full/YLFW_full_info_including_adults.csv', index=False)
