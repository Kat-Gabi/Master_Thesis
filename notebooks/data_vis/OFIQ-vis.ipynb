# %% [markdown]
# # Notebook for visulaising the quality score distributions with OFIQ

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def descriptive_plots_collected(data_path):
    # Load the dataset
    df = pd.read_csv(data_path, sep=';')

    # Histograms for scalar scores
    scalar_columns = [col for col in df.columns if 'scalar' in col]
    df[scalar_columns].hist(bins=20, figsize=(20, 15))
    plt.suptitle('Histograms of Scalar Scores')
    plt.show()

    # # Box plots for raw scores (selecting a subset for visualization purposes)
    # raw_columns = ['UnifiedQualityScore', 'BackgroundUniformity', 'IlluminationUniformity',
    #                'LuminanceMean', 'Sharpness', 'CompressionArtifacts']
    # plt.figure(figsize=(10, 6))
    # df.boxplot(column=raw_columns)
    # plt.xticks(rotation=45)
    # plt.title('Box Plots of Selected Raw Scores')
    # plt.show()

    # # Scatter plot for a pair of attributes (example: UnifiedQualityScore vs. Sharpness)
    # plt.figure(figsize=(10, 6))
    # sns.scatterplot(x='UnifiedQualityScore', y='Sharpness', data=df)
    # plt.title('Scatter Plot of Unified Quality Score vs. Sharpness')
    # plt.show()

    # Improved Box plots for raw scores with Seaborn
    raw_columns = ['UnifiedQualityScore', 'BackgroundUniformity', 'IlluminationUniformity',
                   'LuminanceMean', 'Sharpness', 'CompressionArtifacts']
    plt.figure(figsize=(12, 6))
    sns.boxplot(data=df[raw_columns], palette="Set2")
    plt.xticks(rotation=45)
    plt.title('Box Plots of Selected Raw Scores')
    plt.show()

    # Scatter plot for a pair of attributes (example: UnifiedQualityScore vs. Sharpness) with Seaborn
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x='UnifiedQualityScore', y='Sharpness', data=df, hue='Sharpness', palette='coolwarm', size='Sharpness', sizes=(20, 200))
    plt.title('Scatter Plot of Unified Quality Score vs. Sharpness')
    plt.show()


    # Additional plots can be added based on specific needs or interests

# %%
# data_path_YLFW = '/mnt/c/Dokumenter/Dokumenter/UNI/Master/Thesis/GitHub_Repo/Master_Thesis/data/OFIQ_results/mini/table_YLFW_mini1.csv'
# df = pd.read_csv(data_path_YLFW, sep=';')
# scalar_columns = [col for col in df.columns if 'scalar' in col]
# # df[scalar_columns].hist(bins=20, figsize=(20, 15))

# %%
def Unified_quality_score(data_path):
    # Load the dataset
    df = pd.read_csv(data_path, sep=';')

    # Histograms for scalar scores
    scalar_columns = ['UnifiedQualityScore.scalar']
    df[scalar_columns].hist(bins=20, figsize=(20, 15))
    plt.suptitle('Histograms of Scalar Scores')
    plt.show()


    # Improved Box plots for raw scores with Seaborn
    raw_columns = ['UnifiedQualityScore']
    plt.figure(figsize=(12, 6))
    sns.boxplot(data=df[raw_columns], palette="Set2")
    plt.xticks(rotation=45)
    plt.title('Box Plots of UnifiedQualityScore')
    plt.show()

    # # Scatter plot
    # plt.figure(figsize=(10, 6))
    # sns.scatterplot(x='UnifiedQualityScore', y='Sharpness', data=df, hue='Sharpness', palette='coolwarm', size='Sharpness', sizes=(20, 200))
    # plt.title('Scatter Plot of Unified Quality Score')
    # plt.show()


    # Additional plots can be added based on specific needs or interests

# %%
def descriptive_plots_individual(data_path):
    # Load the dataset
    df = pd.read_csv(data_path, sep=';')

    # Set the aesthetic style of the plots
    sns.set_style("whitegrid")

    # Histograms for scalar scores with Seaborn
    scalar_columns = [col for col in df.columns if 'scalar' in col]
    for col in scalar_columns:
        plt.figure(figsize=(8, 4))
        sns.histplot(df[col], kde=True, bins=20, color='skyblue')
        plt.title(f'Histogram of {col}')
        plt.show()

    # scalar_columns = [col for col in df.columns if 'scalar' in col]
    # for col in scalar_columns:
    #     plt.figure(figsize=(8, 4))
    #     sns.histplot(df[col], kde=True, bins=20, color='skyblue')
    #     plt.title(f'Histogram of {col}')
    #     plt.show()

    # Improved Box plots for raw scores with Seaborn
    raw_columns = ['UnifiedQualityScore', 'BackgroundUniformity', 'IlluminationUniformity',
                   'LuminanceMean', 'Sharpness', 'CompressionArtifacts']
    plt.figure(figsize=(12, 6))
    sns.boxplot(data=df[raw_columns], palette="Set2")
    # sns.boxplot(data=df['scalar_columns'])
    plt.xticks(rotation=45)
    plt.title('Box Plots of Selected Raw Scores')
    plt.show()

    # Scatter plot for a pair of attributes (example: UnifiedQualityScore vs. Sharpness) with Seaborn
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x='UnifiedQualityScore', y='Sharpness', data=df, hue='Sharpness', palette='coolwarm', size='Sharpness', sizes=(20, 200))
    plt.title('Scatter Plot of Unified Quality Score vs. Sharpness')
    plt.show()

    # Additional plots can be added based on specific needs or interests

# %%
def boxplots_individual(data_path):
    # Load the dataset
    df = pd.read_csv(data_path, sep=';')

    # Set the aesthetic style of the plots
    sns.set_style("whitegrid")

    raw_columns = ['UnifiedQualityScore', 'BackgroundUniformity', 'IlluminationUniformity',
                   'LuminanceMean', 'Sharpness', 'CompressionArtifacts']
    for col in raw_columns:
        plt.figure(figsize=(8, 4))
        sns.boxplot(df[col], palette="Set2")
        plt.title(f'Boxplot of Raw scores of {col}')
        plt.show()

# %% [markdown]
# # Adults

# %%
data_path = '/mnt/c/Dokumenter/Dokumenter/UNI/Master/Thesis/GitHub_Repo/Master_Thesis/data/OFIQ_results/adults_all_final.csv'

# descriptive_plots_individual(data_path)
Unified_quality_score(data_path)

# %% [markdown]
# # children

# %%
data_path_children = '/mnt/c/Dokumenter/Dokumenter/UNI/Master/Thesis/GitHub_Repo/Master_Thesis/data/OFIQ_results/children_all_final.csv'

# descriptive_plots_individual(data_path_children)
Unified_quality_score(data_path_children)

# %%
descriptive_plots_individual(data_path_children)

# %% [markdown]
# # OFIQ testdata

# %%
# data_path = '/mnt/c/Dokumenter/Dokumenter/UNI/Master/Thesis/GitHub_Repo/Master_Thesis/data/OFIQ_results/mini/table_OFIQ_testdata.csv'

# descriptive_plots_individual(data_path)

# %% [markdown]
# # YLFW mini

# %%
# data_path_YLFW = '/mnt/c/Dokumenter/Dokumenter/UNI/Master/Thesis/GitHub_Repo/Master_Thesis/data/OFIQ_results/mini/table_YLFW_mini1.csv'

# Unified_quality_score(data_path_YLFW)

# %%
data_path_YLFW = '/mnt/c/Dokumenter/Dokumenter/UNI/Master/Thesis/GitHub_Repo/Master_Thesis/data/OFIQ_results/mini/table_YLFW_mini1.csv'

boxplots_individual(data_path_YLFW)

# %%
data_path_YLFW = '/mnt/c/Dokumenter/Dokumenter/UNI/Master/Thesis/GitHub_Repo/Master_Thesis/data/OFIQ_results/mini/table_YLFW_mini1.csv'

descriptive_plots_collected(data_path_YLFW)

# %%
descriptive_plots_individual(data_path_YLFW)

# %% [markdown]
# # RFW mini
