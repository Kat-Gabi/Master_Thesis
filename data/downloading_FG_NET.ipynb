# %%
import deeplake

ds = deeplake.load("hub://activeloop/fgnet")
# Out:
# -
# Opening dataset in read-only mode as you don't have write permissions.
# /
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/fgnet
# |
# hub://activeloop/fgnet loaded successfully.

# %%
ds
# Out:
# Dataset(path='hub://activeloop/fgnet', read_only=True, tensors=['images', 'keypoints', 'ages', 'image_ids'])

# %%
ds.visualize()
# Out:
# HINT: Please forward the port - 55081 to your local machine, if you are running on the cloud.
#         <iframe
#             width="90%"
#             height="800"
#             src="https://app.activeloop.ai/visualizer/hub?url=hub://activeloop/fgnet&token=PUBLIC_TOKEN_______________________________________________________________________________________________________________________________________________________"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
ds.images[0]
# Out:
# Tensor(key='images', index=Index([0]))

# %%
ds.ages

# get values of tensor
ds.ages
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 4
#       1 ds.ages
#       3 # get values of tensor
# ----> 4 ds.ages.val
#
# AttributeError: 'Tensor' object has no attribute 'val'

# %%
# visualise a tensor
import matplotlib.pyplot as plt
plt.imshow(ds.images[3].numpy())
plt.show()
# Out:
#  * Serving Flask app 'dataset_visualizer'
#  * Debug mode: off

# %%
ds.image_ids[1].numpy()
# Out:
# array([1], dtype=uint32)
